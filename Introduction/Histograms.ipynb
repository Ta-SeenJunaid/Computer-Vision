# %% [markdown]
# # Histograms

# %% [markdown]
# A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data.

# %% [markdown]
# Histograms are a way to visualize individual color components.

# %% [markdown]
# **cv2.calcHist(images, channels, mask, histSize, ranges[, hist[, accumulate]])**
#
# images = Source arrays,
# channels = grayscale:[0], RGB:[0,1,2],
# mask =  Optional mask. If the matrix is not empty, it must be an 8-bit array of the same size as images[i],
# histsize = Output histogram ,
# ranges = Array of the dims arrays of the histogram bin boundaries in each dimension

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('../DATA/bricks.jpg')

#color = ('b', 'g', 'r')

for i, col in enumerate(color):
    histogram = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(histogram, col)
    
    
plt.show()
