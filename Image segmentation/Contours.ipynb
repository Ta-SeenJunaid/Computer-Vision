# %% [markdown]
# # Contours

# %% [markdown]
# Continuous curves having same color or intensity

# %% [markdown]
# ## Uses
# Object detection
# <br />
# Shape analysis
# <br />
# Object recognition

# %% [markdown]
# image, contours, hierarchy = cv2.findContours(source image, contour retrieval mode, contour approximation method)

# %% [markdown]
# Output_image = cv2.drawContours(source_ image, contours, index of contours (-1 for all contours), color, thickness)

# %%
import cv2

img = cv2.imread('../DATA/five_shapes.PNG')

cv2.imshow('Image Input', img)
cv2.waitKey(0)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow('Gray', gray)
cv2.waitKey(0)


edged = cv2.Canny(gray, 30, 200)

cv2.imshow('Canny Edges', edged)
cv2.waitKey(0)

image, contours, hierarchy = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

cv2.imshow('Contours',image)
cv2.waitKey(0)

print(contours)
print("Number of Contours found = " + str(len(contours)))

segmentation = cv2.drawContours(img, contours, -1, (255, 0, 0), 5)

cv2.imshow('Contours', segmentation)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# [array([[[305, 363]],
#
#        [[304, 364]],
#
#        [[303, 364]],
#
#        ...,
#
#        [[308, 363]],
#
#        [[307, 363]],
#
#        [[306, 363]]], dtype=int32), array([[[715, 323]],
#
#        [[714, 324]],
#
#        [[713, 325]],
#
#        ...,
#
#        [[718, 323]],
#
#        [[717, 323]],
#
#        [[716, 323]]], dtype=int32), array([[[198,  71]],
#
#        [[197,  72]],
#
#        [[197,  73]],
#
#        [[196,  74]],
#
#        [[196,  75]],
#
#        [[195,  76]],
#
#        [[194,  77]],
#
#        [[194,  78]],
#
#        [[193,  79]],
#
#        [[192,  80]],
#
#        [[192,  81]],
#
#        [[191,  82]],
#
#        [[191,  83]],
#
#        [[190,  84]],
#
#        [[189,  85]],
#
#        [[189,  86]],
#
#        [[188,  87]],
#
#        [[187,  88]],
#
#        [[187,  89]],
#
#        [[186,  90]],
#
#        [[186,  91]],
#
#        [[185,  92]],
#
#        [[184,  93]],
#
#        [[184,  94]],
#
#        [[183,  95]],
#
# ...

# %% [markdown]
# ## image, contours, hierarchy = cv2.findContours(source image, contour retrieval mode, contour approximation method)
# <br />
# <br />
# contour retrieval mode
# <br />
# RETR_LIST - retrives all contours
# <br />
# RETR_EXTERNAL - retrives outer contours
# <br />
# CV_RETR_CCOMP - retrives 2-level hierarchical contours
# <br />
# RETR_TREE - retrives all in tree format
# <br />
# <br />
# contor approximation method
# <br />
# CHAIN_APPROX_NONE - stores all bounding points
# <br />
# CHAIN_APPROX_SIMPLE - stores only start-end bounding points (an up-right rectangular contour is encoded with 4 points)

# %%
import cv2

img = cv2.imread('../DATA/internal_external.png')

cv2.imshow('Image Input', img)
cv2.waitKey(0)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow('Gray', gray)
cv2.waitKey(0)


edged = cv2.Canny(gray, 30, 200)

cv2.imshow('Canny Edges', edged)
cv2.waitKey(0)

image, contours, hierarchy = cv2.findContours(edged, cv2.RETR_LIST , cv2.CHAIN_APPROX_SIMPLE)

cv2.imshow('Contours',image)
cv2.waitKey(0)

print(contours)
print("Number of Contours found = " + str(len(contours)))

segmentation = cv2.drawContours(img, contours, -1, (255, 0, 0), 2)

cv2.imshow('Contours', segmentation)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# [array([[[189, 499]],
#
#        [[190, 498]],
#
#        [[202, 498]],
#
#        [[203, 499]],
#
#        [[209, 499]],
#
#        [[210, 500]],
#
#        [[210, 502]],
#
#        [[211, 503]],
#
#        [[211, 504]],
#
#        [[212, 505]],
#
#        [[212, 506]],
#
#        [[216, 510]],
#
#        [[217, 510]],
#
#        [[219, 512]],
#
#        [[220, 512]],
#
#        [[221, 513]],
#
#        [[222, 513]],
#
#        [[223, 514]],
#
#        [[224, 514]],
#
#        [[225, 515]],
#
#        [[226, 515]],
#
#        [[227, 516]],
#
#        [[229, 516]],
#
#        [[230, 517]],
#
#        [[233, 517]],
#
#        [[234, 518]],
#
#        [[236, 518]],
#
#        [[237, 519]],
#
#        [[241, 519]],
#
#        [[242, 520]],
#
#        [[246, 520]],
#
#        [[247, 521]],
#
#        [[254, 521]],
#
#        [[255, 522]],
#
#        [[274, 522]],
#
#        [[275, 521]],
#
#        [[282, 521]],
#
#        [[283, 520]],
#
#        [[287, 520]],
#
#        [[288, 519]],
# ...
